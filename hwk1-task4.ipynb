# %% [markdown]
# # Task 4
#
# First, update the following cell to have a link to your Homework 1 GitHub repository:
#
# **Caitlin's homework link: https://github.com/cnordheim-maestas/eds220-hwk-1.git**
#
# In this task, make at least 5 commits at moments you think are adequate. We'll look at your repo to check commit history. Err on the side of commenting too much for now to get in the habit.
#
# Add comments for all your code. Err on the side of commenting too much for now.
#
# Comments in each exercise and commits will count towards your grade.
#
# This task covers topics we will see on Wednesday Oct. 11. You might want to wait until after that class to solve it.
#
# ## Acknowledgement
# This task was adapted from the *Pandas Fundamentals with Earthquake Data* assignment from the e-book [Earth and Environmental Data Science](https://earth-env-data-science.github.io/intro.html)

# %% [markdown]
# ## About the data
#
# For this task we are going to use simplified data from the [USGS Earthquakes Database](https://earthquake.usgs.gov/earthquakes/search/). This dataset is in tabular format and has the following columns:
#
# - time = date and time of event (all events from 2014)
# - latitude = decimal degrees [-90,90]
# - longitude = decimal degrees [-360,360]
# - depth = depth of the event (km)
# - mag =  magnitude of event
# - id = event identifier
# - place = where the event took place
# - type = type of event
#
# ## 1
#
# a. Import pandas (always with standard abbreviation!).
#
# b. Use `pd.read_csv()` to import the `earthquake_data.csv` dataset and store it as `raw_eqk` (variable name).
#
# c. Look at the head of the dataframe.

# %%
# a: import pandas package as "pd"
import pandas as pd

# b: import data as "raw_eqk"
raw_eqk = pd.read_csv('data/earthquake_data.csv')

# c: Look at the head of the dataframe
raw_eqk.head()
# Out:
#                       time   latitude  longitude  depth   mag          id  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10  ak11155107
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33  nn00436847
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30  ak11151142
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80  ak11151135
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34  ci37171541
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# 1            32km S of Alamo, Nevada  earthquake
# 2   12km NNW of North Nenana, Alaska  earthquake
# 3         22km S of Cantwell, Alaska  earthquake
# 4       10km WNW of Progreso, Mexico  earthquake

# %% [markdown]
# ## 2
# a. Print the shape of the `raw_eqk` dataframe.
#
# b. Print the type of `raw_eqk`'s shape.
#
# c. Print *only* the number of rows by accessing it from `raw_eqk`'s shape. HINT: how do you index an element in a tuple?

# %%
# a
# num rows and columns
raw_eqk.shape

# b
# Print the type of shape using print function
print(type(raw_eqk.shape))
# tuple

# c
# get the number of rows using the length function
len(raw_eqk)
# 120108 rows
# Out:
# <class 'tuple'>
# 120108

# %% [markdown]
# ## 3
#
# Get the unique values of the type of events.

# %%
# syntax: df.Column_name.unique()
# Get the unique values in the column "type"
raw_eqk.type.unique()
# Out:
# array(['earthquake', 'quarry blast', 'quarry', 'mining explosion',
#        'rock burst', 'explosion', 'landslide', 'sonicboom', 'sonic boom',
#        'anthropogenic event', 'acoustic noise'], dtype=object)

# %% [markdown]
# # 4
#
# a. Select only earthquake events and store them as `eqk` (variable name)
#
# b. Update the index of `eqk` to be the `id` column of the dataframe.
#
# c. Check the new index by viewing the first 3 rows of `eqk`.

# %%
# a: only earthquake events and store them as eqk

# only select observations where the type column has "earthquake"
eqk = raw_eqk.loc[raw_eqk.type=="earthquake"]

# b: Update the index of eqk to be the id column of the dataframe

# use the pandas set_index function
# syntax: df.set_index(['col_name'])
eqk.set_index(['id'])

# c: view the first 3 rows using head 
eqk.set_index(['id']).head(3)
# Out:
#                                time  latitude  longitude  depth   mag  \
# id
# ak11155107  2014-01-31 23:53:37.000   60.2520  -152.7081   90.2  1.10
# nn00436847  2014-01-31 23:48:35.452   37.0703  -115.1309    0.0  1.33
# ak11151142  2014-01-31 23:47:24.000   64.6717  -149.2528    7.1  1.30
#
#                                         place        type
# id
# ak11155107  26km S of Redoubt Volcano, Alaska  earthquake
# nn00436847            32km S of Alamo, Nevada  earthquake
# ak11151142   12km NNW of North Nenana, Alaska  earthquake

# %% [markdown]
# # 5
#
# How many events were left out of `raw_eqk` when you selected ony earthqake events?
#
# HINT: There are *many* ways you can get this information. One could be to use (2).

# %%
# Calculate the difference of the length of the whole dataset, - length of the earthquake rows

# length of whole dataset - length of earthquake only
print(len(raw_eqk) - len(eqk))

# Answer: 1710
# Out:
# 1710

# %% [markdown]
# # 6
# Without creating any new variables, plot a histogram of the eartquake's magnitudes (`eqk` data). Add a title and change the color of your graph.

# %%
# make a histogram of the values in the magnitude column that is blue with a title
eqk.mag.plot(kind='hist',
            title='Earthquake magnitudes',
            color='blue')
# Out:
# <AxesSubplot:title={'center':'Earthquake magnitudes'}, ylabel='Frequency'>

# %% [markdown]
# # 7
#
# a. Create a new variable `top20` with the 20 earthquakes with largest magnitude. HINT: [`pandas.Series.nlargest`](https://pandas.pydata.org/docs/reference/api/pandas.Series.nlargest.html)
#
# b. Create a bar plot showing the magnitude of the top 20 earthquakes. Update the title, x-axis label, y-axis label, and color of the bars.
#
# c. What is the role of the `top20` index in the graph? What would have happened if we had not updated the index?

# %%
# a: create variable top20 using the nlargest function

#df.column.nlargest(number of values we want, here 20) argument
top20 = eqk.mag.nlargest(20) 

# b: bar plot showing the magnitude of the top 20 earthquakes. 
# Update the title, x-axis label, y-axis label, and color of the bars
top20.plot(kind='bar',
            title='Top 20 Earthquake magnitudes',
           xlabel='Earthquake id',
           ylabel='Magnitude',
            color='blue')

#c: If we had not updated the top20 index, we would get a bar plot wih every single earthquake,
# not just the top 20, which would be a LOT on one graph
# Out:
# <AxesSubplot:title={'center':'Top 20 Earthquake magnitudes'}, xlabel='Earthquake id', ylabel='Magnitude'>

# %% [markdown]
# *If we had not updated the top20 index, we would get a bar plot with every single earthquake, not just the top 20, which would be a LOT on one graph*

# %% [markdown]
# # 8
# We are interested in place, magnitude and depth of the top 20 earthquakes with largest magnitude. Select this data from the `eqk` data frame.
#
# HINT: This is a "select rows and columns simultaneously" from `eqk` exercise. To select the rows you could use the index of `top20`.

# %%
# select specific columns: df[ ['colname1', 'colname2', 'colname3'] ]
# select specific rows: I want the rows that have the same index as the top20 (aka those observations)
# specifically, I want to include a list of the index values of the top20 subset in the first part of the loc
eqk.loc[ top20.index, ['place', 'mag', 'depth'] ] 

# long, manual way: list all of the rows we want by their index
#eqk.loc[ [14025,31496,31850,33537,33808,34318,36918,37367,37371,39915,47934,50562,50609,61294,66278,78063,95913,97602,106285,111052], 
      #  ['place', 'mag', 'depth'] ]
# Out:
#                                           place  mag   depth
# 37371                 94km NW of Iquique, Chile  8.2   25.00
# 50562   19km SE of Little Sitkin Island, Alaska  7.9  109.00
# 36918                 53km SW of Iquique, Chile  7.7   22.40
# 33808     93km SSE of Kirakira, Solomon Islands  7.6   22.56
# 31496      70km SW of Panguna, Papua New Guinea  7.5   43.37
# 33537      112km S of Kirakira, Solomon Islands  7.4   39.00
# 95913           74km S of Intipuca, El Salvador  7.3   40.00
# 31850              33km ESE of Petatlan, Mexico  7.2   24.00
# 34318     56km WSW of Panguna, Papua New Guinea  7.1   60.53
# 106285      154km NW of Kota Ternate, Indonesia  7.1   45.00
# 111052            144km NE of Ndoi Island, Fiji  7.1  434.00
# 97602                Southern East Pacific Rise  7.0   16.54
# 14025                 272km ESE of Hotan, China  6.9   10.00
# 37367                91km WNW of Iquique, Chile  6.9   28.42
# 39915          22km SSW of Kamariotissa, Greece  6.9    6.43
# 47934             154km NNW of Visokoi Island,   6.9    8.00
# 50609     80km SSE of Raoul Island, New Zealand  6.9   20.00
# 61294             99km NNE of Ndoi Island, Fiji  6.9  615.42
# 66278            4km W of Puerto Madero, Mexico  6.9   53.00
# 78063     Federated States of Micronesia region  6.9   13.00

# %% [markdown]
# # 9
#
# Without creating any new variables, visualize the locations of eartquakes with magnitude greter than 5 by creating a scatter plot of their latitude and longitude. Make the following adjustments to the basic plot:
# - update the title
# - color the points by magnitude (HINT: [check the `c` parameter here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.scatter.html))
# - adjust the `alpha` (transparency) argument
# - adjust the `colormap` argument to maket it look prettier. [Click for ideas of sequential colormaps.](https://matplotlib.org/stable/users/explain/colors/colormaps.html)

# %%
# import mpl for colormaps
import matplotlib as mpl

# subset data to only be mag above 5 using the loc function and
# create plot using plot function specifying a scatter plot, the y and x inputs, and
eqk.loc[eqk.mag > 5 ].plot(kind='scatter',
            y='latitude',
             x='longitude',
             alpha=0.4, # transparency of points
             c='mag', # the column the color is decided by
             colormap='inferno' #sequential colormap from mpl
             )
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>
